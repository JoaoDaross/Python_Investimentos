# %% [markdown]
# <a href="https://colab.research.google.com/github/JoaoDaross/Python_Investimentos/blob/master/Investimentos_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Utilizando a linguagem de programação PYTHON para fazer estudos no mercado financeiro.**

# %% [markdown]
# # 1. Importando Bibliotecas

# %% [markdown]
# >Instalando o YFinance

# %%
# !pip install yfinance --upgrade --no-cache-dir
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=a276e9ce82d8969ba408fc2fb04af9c67e970ee379096b2031d53721ebd0b545
#   Stored in directory: /tmp/pip-ephem-wheel-cache-6xlu7re6/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %% [markdown]
# >Importando as Bibliotecas

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pandas_datareader.data as web

import yfinance as yf
yf.pdr_override()
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas_datareader/compat/__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %% [markdown]
# >Importando o YFinance e sobrescrevendo os métodos do `pandas_datareader`

# %%
import yfinance as yf
yf.pdr_override()

# %% [markdown]
# # 2.Obtendo os dados do mercado

# %% [markdown]
# >Baixando as cotações do Yahoo Finance para o Índice Bovespa

# %%
ibov = web.get_data_yahoo('^BVSP')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# >Exibindo as cotações mais antigas

# %%
ibov.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 1993-04-27  24.799999  25.400000  24.500000  24.500000  24.500000       0
# 1993-04-28  24.500000  24.600000  23.700001  24.299999  24.299999       0
# 1993-04-29  24.299999  24.799999  23.700001  23.700001  23.700001       0
# 1993-04-30  23.700001  24.200001  23.700001  24.100000  24.100000       0
# 1993-05-03  24.100000  24.400000  23.799999  24.100000  24.100000       0

# %% [markdown]
# >Exibindo as cotações mais recentes

# %%
ibov.tail()
# Out:
#                     Open          High  ...     Adj Close   Volume
# Date                                    ...
# 2020-09-22  96995.000000  97684.000000  ...  97294.000000  7281300
# 2020-09-23  97294.000000  97389.000000  ...  95735.000000  8830700
# 2020-09-24  95735.000000  97955.000000  ...  97012.000000  9331000
# 2020-09-25  97011.000000  97012.000000  ...  96999.000000  7351100
# 2020-09-28  97005.382812  98162.023438  ...  98162.023438        0
#
# [5 rows x 6 columns]

# %% [markdown]
# >Plotando o gráfico com o preços de fechamento do Índice Bovespa

# %%
ibov['Close'].plot(figsize=(22,10))

# %% [markdown]
# >Plotando o gráfico com o preços de fechamento do Índice Bovespa com média móvel de 21 e 200 dias.

# %%
ibov["Close"].plot(figsize=(22,8), label="IBOV")
ibov["Close"].rolling(21).mean().plot(label="MM21")
ibov["Close"].rolling(200).mean().plot(label="MM200")
plt.legend();

# %% [markdown]
# >Plotando o gráfico com o preços de fechamento do Índice Bovespa com média móvel de 21 e 200 dias filtrado pelo ano de 2018

# %%
ibov_fatiado = ibov[ibov.index.year == 2018]
ibov_fatiado["Close"].plot(figsize=(22,8), label="IBOV")
ibov_fatiado["Close"].rolling(21).mean().plot(label="MM21")
ibov_fatiado["Close"].rolling(200).mean().plot(label="MM200")
plt.legend();

# %% [markdown]
# >Plotando o gráfico com o preços de fechamento do Índice Bovespa com média móvel de 21 e 200 dias filtrado pelo periodo de 2015 até 2019
#
# 1.   List item
# 2.   List item

# %%
ibov_fatiado = ibov[(ibov.index.year >= 2015) & (ibov.index.year <= 2019)]
ibov_fatiado["Close"].plot(figsize=(22,8), label="IBOV")
ibov_fatiado["Close"].rolling(21).mean().plot(label="MM21")
ibov_fatiado["Close"].rolling(200).mean().plot(label="MM200")
plt.legend();

# %% [markdown]
# >Tabela com os últimos 20 preços de fechamento do Índice Bovespa filtrado pelo mês de dezembro.

# %%
ibov_fatiado = ibov[ibov.index.month == 12]
ibov_fatiado.tail(20)
# Out:
#                 Open      High       Low     Close  Adj Close   Volume
# Date
# 2018-12-28   85469.0   88044.0   85469.0   87887.0    87887.0  3649100
# 2019-12-02  108246.0  109279.0  108245.0  109061.0   109061.0  4708000
# 2019-12-03  108931.0  109198.0  108190.0  108956.0   108956.0  5223100
# 2019-12-04  108962.0  110301.0  108962.0  110301.0   110301.0  4889500
# 2019-12-05  110297.0  111073.0  110008.0  110622.0   110622.0  4399100
# 2019-12-06  110623.0  111430.0  110623.0  111126.0   111126.0  4968100
# 2019-12-09  111125.0  111453.0  110870.0  110977.0   110977.0  4991500
# 2019-12-10  110973.0  111184.0  110133.0  110672.0   110672.0  4758800
# 2019-12-11  110672.0  111227.0  110530.0  110964.0   110964.0  5146100
# 2019-12-12  110963.0  112445.0  110963.0  112200.0   112200.0  5682000
# 2019-12-13  112205.0  112829.0  111780.0  112565.0   112565.0  7712100
# 2019-12-16  112565.0  113197.0  111896.0  111896.0   111896.0  6078300
# ...

# %% [markdown]
# >Tabela com os últimos 20 preços de fechamento do Índice Bovespa filtrado pelo dia 14 de cada mês.

# %%
ibov_fatiado = ibov[ibov.index.day == 14]
ibov_fatiado.tail(20)
# Out:
#                 Open      High       Low     Close  Adj Close    Volume
# Date
# 2018-06-14   72151.0   72708.0   71344.0   71421.0    71421.0   4281600
# 2018-08-14   77499.0   78742.0   77499.0   78602.0    78602.0   3713000
# 2018-09-14   74687.0   75705.0   74445.0   75429.0    75429.0   3231700
# 2018-11-14   84898.0   85973.0   84267.0   85973.0    85973.0   5591600
# 2018-12-14   87838.0   88184.0   87106.0   87450.0    87450.0   3553300
# 2019-01-14   93645.0   94474.0   93335.0   94474.0    94474.0   4486900
# 2019-02-14   95843.0   98019.0   94915.0   98015.0    98015.0   5222300
# 2019-03-14   98905.0   99036.0   97776.0   98605.0    98605.0   3584500
# 2019-05-14   91736.0   92529.0   91562.0   92092.0    92092.0   4045400
# 2019-06-14   98776.0   98981.0   97601.0   98040.0    98040.0   9184900
# 2019-08-14  103270.0  103270.0   99955.0  100258.0   100258.0   6485200
# 2019-10-14  103834.0  104305.0  103438.0  104302.0   104302.0   2987900
# ...
